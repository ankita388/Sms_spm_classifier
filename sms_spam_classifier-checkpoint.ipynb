# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1')

# %%
df.sample(5)
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 1866  ham     Or Ì_ go buy wif him then i meet Ì_ later can?        NaN
# 3918  ham  I wish! I don't think its gonna snow that much...        NaN
# 644   ham  Allo! We have braved the buses and taken on th...        NaN
# 3375  ham  Good afternon, my love. How are today? I hope ...        NaN
# 2516  ham                             Yes.i'm in office da:)        NaN
#
#      Unnamed: 3 Unnamed: 4
# 1866        NaN        NaN
# 3918        NaN        NaN
# 644         NaN        NaN
# 3375        NaN        NaN
# 2516        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
# 1. Data cleaning
# 2. EDA
# 3. Text Preprocessing
# 4. Model building
# 5. Evaluation
# 6. Improvement
# 7. Website
# 8. Deploy

# %% [markdown]
# # 1. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
# drop last 3 cols
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],inplace=True)

# %%
df.sample(5)
# Out:
#        v1                                                 v2
# 2167  ham                   Yes.he have good crickiting mind
# 2629  ham  Hey there! Glad u r better now. I hear u treat...
# 4131  ham  Hi baby ive just got back from work and i was ...
# 2374  ham                           Dunno lei he neva say...
# 4130  ham  \Its Ur luck to Love someone. Its Ur fortune t...

# %%
# renaming the cols
df.rename(columns={'v1':'target','v2':'text'},inplace=True)
df.sample(5)
# Out:
#      target                                               text
# 3465    ham  Actually fuck that, just do whatever, do find ...
# 1060    ham  I'm working technical support :)voice process....
# 3004    ham                            Ew are you one of them?
# 3017    ham       I didn't get the second half of that message
# 5159    ham                       No but the bluray player can

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
df['target'] = encoder.fit_transform(df['target'])

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# missing values
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check for duplicate values
df.duplicated().sum()
# Out:
# 403

# %%
# remove duplicates
df = df.drop_duplicates(keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# # 2. EDA

# %%
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
df['target'].value_counts()
# Out:
# target
# 0    4516
# 1     653
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df['target'].value_counts(), labels=['ham','spam'],autopct="%0.2f")
plt.show()

# %%
# Data is imbalanced so
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Ankita
# [nltk_data]     Konar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
df['num_characters'] = df['text'].apply(len)

# %%
df.head()
# Out:
#    target                                               text  num_characters
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61

# %%
df['num_words'] = df['text'].apply(lambda x: len(str(x).split()))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words
# 0         20
# 1          6
# 2         28
# 3         11
# 4         13

# %%
df['num_sentences'] = df['text'].apply(lambda x: len(str(x).split('.')))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences
# 0         20              9
# 1          6              7
# 2         28              2
# 3         11              7
# 4         13              1

# %%
df[['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     5169.000000  5169.000000    5169.000000
# mean        78.977945    15.340685       2.934030
# std         58.236293    11.068488       2.541852
# min          2.000000     1.000000       1.000000
# 25%         36.000000     7.000000       1.000000
# 50%         60.000000    12.000000       2.000000
# 75%        117.000000    22.000000       4.000000
# max        910.000000   171.000000      42.000000

# %%
# ham
df[df['target'] == 0][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters    num_words  num_sentences
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    14.134632       2.916519
# std         56.358207    11.116240       2.638732
# min          2.000000     1.000000       1.000000
# 25%         34.000000     7.000000       1.000000
# 50%         52.000000    11.000000       2.000000
# 75%         90.000000    18.000000       4.000000
# max        910.000000   171.000000      42.000000

# %%
#spam
df[df['target'] == 1][['num_characters','num_words','num_sentences']].describe()
# Out:
#        num_characters   num_words  num_sentences
# count      653.000000  653.000000     653.000000
# mean       137.891271   23.681470       3.055130
# std         30.137753    5.967672       1.725848
# min         13.000000    2.000000       1.000000
# 25%        132.000000   22.000000       2.000000
# 50%        149.000000   25.000000       3.000000
# 75%        157.000000   28.000000       4.000000
# max        224.000000   35.000000      14.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_characters'])
sns.histplot(df[df['target'] == 1]['num_characters'],color='red')
# Out:
# <Axes: xlabel='num_characters', ylabel='Count'>

# %%
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 0]['num_words'])
sns.histplot(df[df['target'] == 1]['num_words'],color='red')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df,hue='target')

# %%
numeric_df = df.select_dtypes(include='number')

# Step 2: Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    numeric_df.corr(),
    annot=True,
    vmin=0.0, vmax=1.0,
    cbar_kws={'ticks': np.arange(0.0, 1.1, 0.1)},
    cmap='Spectral'  # You can also try 'magma', 'coolwarm', 'viridis', etc.
)
plt.title("Correlation Heatmap (Numeric Features Only)", fontsize=14)
plt.show()

# %% [markdown]
# # 3. Data Preprocessing

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Ankita
# [nltk_data]     Konar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords

# %%
# Check if it loads without error
print(stopwords.words('english')[:10])
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

ps = PorterStemmer()

def transform_text(text):
    # Lowercase
    text = text.lower()

    # Tokenization using regex instead of nltk.word_tokenize
    words = re.findall(r'\b\w+\b', text)

    # Remove stopwords
    filtered = [word for word in words if word not in stopwords.words('english')]

    # Stemming
    stemmed = [ps.stem(word) for word in filtered]

    return " ".join(stemmed)

# Example usage
output = transform_text("I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today.")
print(output)
# Out:
# gonna home soon want talk stuff anymor tonight k cri enough today

# %%
df['text'][10]
# Out:
# "I'm gonna be home soon and i don't want to talk about this stuff anymore tonight, k? I've cried enough today."

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
ps.stem('loving')
# Out:
# 'love'

# %%
df['transformed_text'] = df['text'].apply(transform_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         20              9  go jurong point crazi avail bugi n great world...
# 1          6              7                              ok lar joke wif u oni
# 2         28              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         11              7                u dun say earli hor u c alreadi say
# 4         13              1               nah think goe usf live around though

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ankita konar\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\ankita konar\anaconda3\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\ankita konar\anaconda3\lib\site-packages (from wordcloud) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ankita konar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ankita konar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ankita konar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ankita konar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ankita konar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ankita konar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ankita konar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ankita konar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
from wordcloud import WordCloud
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

# %%
spam_wc = wc.generate(df[df['target'] == 1]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(spam_wc)

# %%
ham_wc = wc.generate(df[df['target'] == 0]['transformed_text'].str.cat(sep=" "))

# %%
plt.figure(figsize=(15,6))
plt.imshow(ham_wc)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         20              9  go jurong point crazi avail bugi n great world...
# 1          6              7                              ok lar joke wif u oni
# 2         28              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         11              7                u dun say earli hor u c alreadi say
# 4         13              1               nah think goe usf live around though

# %%
spam_corpus = []
for msg in df[df['target'] == 1]['transformed_text'].tolist():
    for word in msg.split():
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 11996

# %%
from collections import Counter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Prepare the data
common_words = pd.DataFrame(Counter(spam_corpus).most_common(30), columns=['word', 'count'])

# Create rainbow-style color palette
rainbow_colors = sns.color_palette("hsv", len(common_words))  # hsv gives rainbow hues

# Plot with colorful bars
plt.figure(figsize=(12,6))
sns.barplot(x='word', y='count', data=common_words, palette=rainbow_colors)
plt.xticks(rotation='vertical')
plt.title("Top 30 Most Common Words in Spam Messages (Rainbow Style)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ankita Konar\AppData\Local\Temp\ipykernel_11604\3710697476.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='word', y='count', data=common_words, palette=rainbow_colors)

# %%
ham_corpus = []
for msg in df[df['target'] == 0]['transformed_text'].tolist():
    for word in msg.split():
        ham_corpus.append(word)

# %%
len(ham_corpus)
# Out:
# 36510

# %%
from collections import Counter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Create a DataFrame of top 30 words
ham_words_df = pd.DataFrame(Counter(ham_corpus).most_common(30), columns=['word', 'count'])

# Use a distinct qualitative color palette (like Set3 or Paired)
color_palette = sns.color_palette("Set3", n_colors=len(ham_words_df))  # pastel but diverse colors

# Plotting
plt.figure(figsize=(12, 6))
sns.barplot(x='word', y='count', data=ham_words_df, palette=color_palette)
plt.xticks(rotation='vertical')
plt.title("Top 30 Most Common Words in Ham Messages", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Ankita Konar\AppData\Local\Temp\ipykernel_11604\2485353436.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='word', y='count', data=ham_words_df, palette=color_palette)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentences                                   transformed_text
# 0         20              9  go jurong point crazi avail bugi n great world...
# 1          6              7                              ok lar joke wif u oni
# 2         28              2  free entri 2 wkli comp win fa cup final tkt 21...
# 3         11              7                u dun say earli hor u c alreadi say
# 4         13              1               nah think goe usf live around though

# %% [markdown]
# # 4. Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv = CountVectorizer()
tfidf = TfidfVectorizer(max_features=3000)

# %%
X = tfidf.fit_transform(df['transformed_text']).toarray()

# %%
X.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.naive_bayes import GaussianNB,MultinomialNB,BernoulliNB
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score

# %%
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train,y_train)
y_pred1 = gnb.predict(X_test)
print(accuracy_score(y_test,y_pred1)*100)
print(confusion_matrix(y_test,y_pred1))
print(precision_score(y_test,y_pred1))
# Out:
# 87.71760154738878
# [[790 106]
#  [ 21 117]]
# 0.5246636771300448

# %%
mnb.fit(X_train,y_train)
y_pred2 = mnb.predict(X_test)
print(accuracy_score(y_test,y_pred2)*100)
print(confusion_matrix(y_test,y_pred2))
print(precision_score(y_test,y_pred2))
# Out:
# 97.678916827853
# [[896   0]
#  [ 24 114]]
# 1.0

# %%
bnb.fit(X_train,y_train)
y_pred3 = bnb.predict(X_test)
print(accuracy_score(y_test,y_pred3)*100)
print(confusion_matrix(y_test,y_pred3))
print(precision_score(y_test,y_pred3))
# Out:
# 98.74274661508704
# [[895   1]
#  [ 12 126]]
# 0.9921259842519685

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.3-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\ankita konar\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\ankita konar\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.0.3-py3-none-win_amd64.whl (149.9 MB)
#    ---------------------------------------- 0.0/149.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0
#    -------------------------------------- - 145.8/149.9 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 145.8/149.9 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 145.8/149.9 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 145.8/149.9 MB 3.8 MB/s eta 0:00:02
#    -------------------------------------- - 146.0/149.9 MB 3.7 MB/s eta 0:00:02
#    ---------------------------------------  146.3/149.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  146.3/149.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  146.5/149.9 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------  146.8/149.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  147.1/149.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  147.1/149.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  147.3/149.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  147.6/149.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  147.8/149.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  148.1/149.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  148.4/149.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  148.6/149.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  148.9/149.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  149.2/149.9 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  149.4/149.9 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  149.7/149.9 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  149.7/149.9 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 149.9/149.9 MB 3.3 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.3

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc,
    'NB': mnb,
    'DT': dtc,
    'LR': lrc,
    'RF': rfc,
    'AdaBoost': abc,
    'BgC': bc,
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)

    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9758220502901354, 0.9747899159663865)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():

    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)

    print("For ",name)
    print("Accuracy - ",current_accuracy*100)
    print("Precision - ",current_precision)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  97.58220502901354
# Precision -  0.9747899159663865
# For  KN
# Accuracy -  90.42553191489363
# Precision -  1.0
# For  NB
# Accuracy -  97.678916827853
# Precision -  1.0
# For  DT
# Accuracy -  93.7137330754352
# Precision -  0.8476190476190476
# For  LR
# Accuracy -  96.0348162475822
# Precision -  0.9619047619047619
# For  RF
# Accuracy -  97.48549323017409
# Precision -  0.9745762711864406
# C:\Users\Ankita Konar\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# For  AdaBoost
# Accuracy -  96.80851063829788
# Precision -  0.9487179487179487
# For  BgC
# Accuracy -  95.74468085106383
# Precision -  0.8405797101449275
# For  ETC
# Accuracy -  97.96905222437138
# Precision -  0.975609756097561
# For  GBDT
# Accuracy -  95.06769825918762
# Precision -  0.9484536082474226
# For  xgb
# Accuracy -  97.678916827853
# Precision -  0.9523809523809523

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores}).sort_values('Precision',ascending=False)

# %%
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 1         KN  0.904255   1.000000
# 2         NB  0.976789   1.000000
# 8        ETC  0.979691   0.975610
# 0        SVC  0.975822   0.974790
# 5         RF  0.974855   0.974576
# 4         LR  0.960348   0.961905
# 10       xgb  0.976789   0.952381
# 6   AdaBoost  0.968085   0.948718
# 9       GBDT  0.950677   0.948454
# 3         DT  0.937137   0.847619
# 7        BgC  0.957447   0.840580

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")

# %%
performance_df1
# Out:
#    Algorithm   variable     value
# 0         KN   Accuracy  0.904255
# 1         NB   Accuracy  0.976789
# 2        ETC   Accuracy  0.979691
# 3        SVC   Accuracy  0.975822
# 4         RF   Accuracy  0.974855
# 5         LR   Accuracy  0.960348
# 6        xgb   Accuracy  0.976789
# 7   AdaBoost   Accuracy  0.968085
# 8       GBDT   Accuracy  0.950677
# 9         DT   Accuracy  0.937137
# 10       BgC   Accuracy  0.957447
# 11        KN  Precision  1.000000
# 12        NB  Precision  1.000000
# 13       ETC  Precision  0.975610
# 14       SVC  Precision  0.974790
# 15        RF  Precision  0.974576
# 16        LR  Precision  0.961905
# 17       xgb  Precision  0.952381
# 18  AdaBoost  Precision  0.948718
# 19      GBDT  Precision  0.948454
# 20        DT  Precision  0.847619
# 21       BgC  Precision  0.840580
